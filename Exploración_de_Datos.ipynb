# %%
import urllib3 # importar la librería
from pandas import read_csv
from pandas import read_excel
import pandas as pd

# %%
import openpyxl

# %%
import re

df = df.applymap(lambda x: re.sub(r'[^a-zA-Z0-9\s]', '', x))

# %%
PATH = "https://raw.githubusercontent.com/PacktPublishing/Pandas-Cookbook-Second-Edition/master/data/restaurant_inspections.csv"
HTTPS = urllib3.PoolManager()
URL = HTTPS.request("GET", PATH)

print("Status: ",URL.status)
# Out:
# Status:  200

# %%
import pandas as pd
from os import read
df = read_csv (PATH)

# %%
df = read_csv(PATH) #d.f Data Frame

# %%
df.head (11) #primeras filas del DataFrame
# Out:
#                   Name        Date         Info  \
# 0    E & E Grill House  2017-08-08      Borough
# 1    E & E Grill House  2017-08-08      Cuisine
# 2    E & E Grill House  2017-08-08  Description
# 3    E & E Grill House  2017-08-08        Grade
# 4    E & E Grill House  2017-08-08        Score
# 5          PIZZA WAGON  2017-04-12      Borough
# 6          PIZZA WAGON  2017-04-12      Cuisine
# 7          PIZZA WAGON  2017-04-12  Description
# 8          PIZZA WAGON  2017-04-12        Grade
# 9          PIZZA WAGON  2017-04-12        Score
# 10  NY SWEET SPOT CAFE  2017-03-28      Borough
#
#                                                 Value
# 0                                           MANHATTAN
# 1                                            American
# 2   Non-food contact surface improperly constructe...
# 3                                                   A
# 4                                                 9.0
# 5                                            BROOKLYN
# ...

# %%
df.shape #mostrar informacion de filas y columnas
# Out:
# (500, 4)

# %%
df.info() #mostrar informacion
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    500 non-null    object
#  1   Date    500 non-null    object
#  2   Info    500 non-null    object
#  3   Value   500 non-null    object
# dtypes: object(4)
# memory usage: 15.8+ KB

# %%
df.isnull().sum() #mostrar informacion #ausencia de datos
# Out:
# Name     0
# Date     0
# Info     0
# Value    0
# dtype: int64

# %%
df["Value"] #seleccionar una columna
# Out:
# 0                                              MANHATTAN
# 1                                               American
# 2      Non-food contact surface improperly constructe...
# 3                                                      A
# 4                                                    9.0
#                              ...
# 495                                            MANHATTAN
# 496                                             American
# 497    Filth flies or food/refuse/sewage-associated (...
# 498                                                    Z
# 499                                                 33.0
# Name: Value, Length: 500, dtype: object

# %%
df [["Date","Name"]] #mostrar varias columnas
# Out:
#            Date                           Name
# 0    2017-08-08              E & E Grill House
# 1    2017-08-08              E & E Grill House
# 2    2017-08-08              E & E Grill House
# 3    2017-08-08              E & E Grill House
# 4    2017-08-08              E & E Grill House
# ..          ...                            ...
# 495  2017-09-01  PIER SIXTY ONE-THE LIGHTHOUSE
# 496  2017-09-01  PIER SIXTY ONE-THE LIGHTHOUSE
# 497  2017-09-01  PIER SIXTY ONE-THE LIGHTHOUSE
# 498  2017-09-01  PIER SIXTY ONE-THE LIGHTHOUSE
# 499  2017-09-01  PIER SIXTY ONE-THE LIGHTHOUSE
#
# [500 rows x 2 columns]

# %%
df[df["Name"] < "E & E Grill House"] #filtrar filas del DataFrame en base a una condicion
# Out:
#                    Name        Date         Info  \
# 20   BRANDY'S PIANO BAR  2017-07-24      Borough
# 21   BRANDY'S PIANO BAR  2017-07-24      Cuisine
# 22   BRANDY'S PIANO BAR  2017-07-24  Description
# 23   BRANDY'S PIANO BAR  2017-07-24        Grade
# 24   BRANDY'S PIANO BAR  2017-07-24        Score
# ..                  ...         ...          ...
# 480      CIPRIANI DOLCI  2017-01-17      Borough
# 481      CIPRIANI DOLCI  2017-01-17      Cuisine
# 482      CIPRIANI DOLCI  2017-01-17  Description
# 483      CIPRIANI DOLCI  2017-01-17        Grade
# 484      CIPRIANI DOLCI  2017-01-17        Score
#
#                                                  Value
# 20                                           MANHATTAN
# 21                                            American
# 22   Non-food contact surface improperly constructe...
# 23                                                   A
# 24                                                 9.0
# ...

# %%
df.insert(3,"Customers per day","") #anadir columna al df

# %%
df.head(5)
# Out:
#                 Name        Date         Info Customers per day  \
# 0  E & E Grill House  2017-08-08      Borough
# 1  E & E Grill House  2017-08-08      Cuisine
# 2  E & E Grill House  2017-08-08  Description
# 3  E & E Grill House  2017-08-08        Grade
# 4  E & E Grill House  2017-08-08        Score
#
#                                                Value
# 0                                          MANHATTAN
# 1                                           American
# 2  Non-food contact surface improperly constructe...
# 3                                                  A
# 4                                                9.0

# %%
df.drop(columns = ['Date']) #eliminar una o varias columnas del df
# Out:
#                               Name         Info Customers per day  \
# 0                E & E Grill House      Borough
# 1                E & E Grill House      Cuisine
# 2                E & E Grill House  Description
# 3                E & E Grill House        Grade
# 4                E & E Grill House        Score
# ..                             ...          ...               ...
# 495  PIER SIXTY ONE-THE LIGHTHOUSE      Borough
# 496  PIER SIXTY ONE-THE LIGHTHOUSE      Cuisine
# 497  PIER SIXTY ONE-THE LIGHTHOUSE  Description
# 498  PIER SIXTY ONE-THE LIGHTHOUSE        Grade
# 499  PIER SIXTY ONE-THE LIGHTHOUSE        Score
#
#                                                  Value
# 0                                            MANHATTAN
# 1                                             American
# 2    Non-food contact surface improperly constructe...
# 3                                                    A
# 4                                                  9.0
# ...

# %%
df.loc[:, 'Date']
# Out:
# 0      20170808
# 1      20170808
# 2      20170808
# 3      20170808
# 4      20170808
#          ...
# 495    20170901
# 496    20170901
# 497    20170901
# 498    20170901
# 499    20170901
# Name: Date, Length: 500, dtype: object

# %%
df.loc[6]
# Out:
# Name                 PIZZA WAGON
# Date                  2017-04-12
# Info                     Cuisine
# Customers per day
# Value                      Pizza
# Name: 6, dtype: object

# %%
df.to_csv("df.csv", sep=",", encoding= 'UTF-8', index=False)

# %%
df.to_excel("df.xlsx") #exporar el df a un archivo Excel

# %%
 df.to_csv("df.csv", sep = ",", encoding = 'UTF-8',index = False)
